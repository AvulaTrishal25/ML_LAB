# %%
import matplotlib.pyplot as plt
from scipy import stats

x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
x1=[5,7,8,7,2,9,4,11,12,9,6]
y1=[99,86,87,88,103,87,94,78,77,85,86]

# %%
plt.scatter(x,y)
plt.xlabel("years after purchase")
plt.ylabel("resale value")
plt.show()

# %%
slope,intercept,r,p,std_err=stats.linregress(x,y)

def myfunc(x):
    return slope*x+intercept

mymodel1=list(map(myfunc,x))
print(mymodel1)
mymodel2=list(map(myfunc,x))
print(mymodel2)
# Out:
# [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]
# [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]

# %%
slope,intercept,r,p,std_err=stats.linregress(x,y)

def myfunc(x):
    return slope*x+intercept

mymodel1=list(map(myfunc,x))
print(mymodel1)

slope,intercept,r,p,std_err=stats.linregress(x1,y1)

def myfunc(x1):
    return slope*x1+intercept

mymodel2=list(map(myfunc,x1))
print(mymodel2)
print(r*r)
# Out:
# [94.3495217071376, 90.84694628403238, 89.09565857247976, 90.84694628403238, 99.60338484179543, 73.33406916850626, 99.60338484179543, 87.34437086092716, 96.10080941869022, 83.84179543782193, 82.09050772626932, 87.34437086092716, 92.59823399558499]
# [93.78865979381443, 88.85463917525774, 86.3876288659794, 88.85463917525774, 101.18969072164948, 83.92061855670104, 96.25567010309278, 78.98659793814434, 76.51958762886599, 83.92061855670104, 91.32164948453608]
# 0.8633453743935495

# %%
plt.scatter(x,y)
fig1=plt.plot(x,mymodel1,lw=4,c='orange',label='full')
fig2=plt.plot(x1,mymodel2,lw=4,c='green',label='outlier removed')
plt.xlabel("years of purchase")
plt.ylabel("resale value")
plt.legend()
plt.show()
